# %%
var1 = "Hello"
var1
# Out:
# 'Hello'

# %%
item = 101
print (type(item))
# Out:
# <class 'int'>

# %%
item = "Code 101"
print(type(item))
# Never use same variable name for all data types
# Out:
# <class 'str'>

# %%
import math
print("When Comparning the floats we may run into precision issues:")
print(0.3 == 0.1 * 3)
print(type(0.1))
math.isclose(0.3, 0.1 * 3)
# Out:
# When Comparning the floats we may run into precision issues:
# False
# <class 'float'>
# True

# %%
# The true division is always return float, it is independed on operands
# But the floor divsion depends on the operands. 
print(5//3.0) # will result in float as a result
print(8/2) # will always result in result as float.
print(5//3) # will result in int as a result
# Out:
# 1.0
# 4.0
# 1

# %%
course = "    python for devops"
print(course)
print(f"Resulr of .strip(): {course.strip()}")
print(f"Result of .lstrip(): {course.lstrip()}")
print(f"Result of .rstrip(): {course.rstrip()}")
print(f"result of .upper(): {course.upper()}")
print(f"resulr of .lower(): {course.lower()}")

file_name = "file.yaml"
print(file_name.startswith("file"))
print(file_name.endswith("yaml"))

path="/var/local/bin"
parts_split = path.split("/")
print(f"path joined: {"\\".join(parts_split)}")
# Out:
#     python for devops
# Resulr of .strip(): python for devops
# Result of .lstrip(): python for devops
# Result of .rstrip():     python for devops
# result of .upper():     PYTHON FOR DEVOPS
# resulr of .lower():     python for devops
# True
# True
# path joined: \var\local\bin
